# %% [markdown]
# ## Load Packages and Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from random import sample
from random import seed
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
SEED = 456
TEST = 0.2
PATH = "Data/"

# %%
nyc_restaurants = pd.read_csv(PATH + "DOHMH_New_York_City_Restaurant_Inspection_Results.csv")
nyc_restaurants = nyc_restaurants.iloc[:, 0:20]
nyc_restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198622 entries, 0 to 198621
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  198622 non-null  int64
#  1   DBA                    196857 non-null  object
#  2   BORO                   198622 non-null  object
#  3   BUILDING               198255 non-null  object
#  4   STREET                 198595 non-null  object
#  5   ZIPCODE                195922 non-null  float64
#  6   PHONE                  198612 non-null  object
#  7   CUISINE DESCRIPTION    194269 non-null  object
#  8   INSPECTION DATE        198622 non-null  object
#  9   ACTION                 194269 non-null  object
#  10  VIOLATION CODE         193179 non-null  object
#  11  VIOLATION DESCRIPTION  193179 non-null  object
#  12  CRITICAL FLAG          198622 non-null  object
#  13  SCORE                  187609 non-null  float64
#  14  GRADE                  96904 non-null   object
#  15  GRADE DATE             89521 non-null   object
#  16  RECORD DATE            198622 non-null  object
#  17  INSPECTION TYPE        194269 non-null  object
#  18  Latitude               198319 non-null  float64
#  19  Longitude              198319 non-null  float64
# dtypes: float64(4), int64(1), object(15)
# memory usage: 30.3+ MB

# %%
["{}: {}".format(column, nyc_restaurants[column].isna().sum()) for column in nyc_restaurants.columns]
# Out:
# ['CAMIS: 0',
#  'DBA: 1765',
#  'BORO: 0',
#  'BUILDING: 367',
#  'STREET: 27',
#  'ZIPCODE: 2700',
#  'PHONE: 10',
#  'CUISINE DESCRIPTION: 4353',
#  'INSPECTION DATE: 0',
#  'ACTION: 4353',
#  'VIOLATION CODE: 5443',
#  'VIOLATION DESCRIPTION: 5443',
#  'CRITICAL FLAG: 0',
#  'SCORE: 11013',
#  'GRADE: 101718',
#  'GRADE DATE: 109101',
#  'RECORD DATE: 0',
#  'INSPECTION TYPE: 4353',
#  'Latitude: 303',
#  'Longitude: 303']

# %% [markdown]
# ## Unscored Data

# %%
scoreless_idx = np.where(nyc_restaurants.SCORE.isna() == True)
scoreless = nyc_restaurants.iloc[scoreless_idx]
["{}: {}".format(column, scoreless[column].isna().sum()) for column in scoreless.columns]

# most unscored restaurants correlate with missing name, cuisine info, action, inspection type,
# violation code and description above (missing other data)
# Out:
# ['CAMIS: 0',
#  'DBA: 1765',
#  'BORO: 0',
#  'BUILDING: 50',
#  'STREET: 27',
#  'ZIPCODE: 171',
#  'PHONE: 1',
#  'CUISINE DESCRIPTION: 4353',
#  'INSPECTION DATE: 0',
#  'ACTION: 4353',
#  'VIOLATION CODE: 4825',
#  'VIOLATION DESCRIPTION: 4825',
#  'CRITICAL FLAG: 0',
#  'SCORE: 11013',
#  'GRADE: 10995',
#  'GRADE DATE: 11010',
#  'RECORD DATE: 0',
#  'INSPECTION TYPE: 4353',
#  'Latitude: 66',
#  'Longitude: 66']

# %% [markdown]
# ## Populate Missing Grades with Score (Target Variable)

# %%
# fill rating with score (then drop score col)

# A <=13, 14 < B <= 27, C >= 28
# Grade associated with the inspection; 
# • N = Not Yet Graded (7394) • A = Grade A (68901) • B = Grade B (10049) 
# • C = Grade C (5297) • Z = Grade Pending (4695) • P = Grade Pending 
# issued on re-opening following an initial inspection that resulted in a closure (568)

# 11,013 missing scores - Drop columns
nyc_restaurants = nyc_restaurants.dropna(subset = "SCORE").reset_index(drop = True)

i = 0
while i < len(nyc_restaurants):
    if nyc_restaurants["SCORE"][i] <= 13:
        nyc_restaurants.iloc[i, nyc_restaurants.columns.get_loc("GRADE")] = "A"
    elif nyc_restaurants["SCORE"][i] <= 27:
        nyc_restaurants.iloc[i, nyc_restaurants.columns.get_loc("GRADE")] = "B"
    elif nyc_restaurants["SCORE"][i] > 27:
        nyc_restaurants.iloc[i, nyc_restaurants.columns.get_loc("GRADE")] = "C"
    i += 1

# %%
display("Median: {}".format(np.median(nyc_restaurants.SCORE)))
display("Mean: {:.1f}".format(np.mean(nyc_restaurants.SCORE)))
score_3rdq = nyc_restaurants.sort_values(by = "SCORE", ascending = True).\
iloc[np.ceil(.75*(len(nyc_restaurants)+1)).astype('int32')].SCORE

display("3rd Quartile: {}".format(score_3rdq))

scoreplot = sns.histplot(nyc_restaurants.SCORE)
scoreplot.axvline(score_3rdq, color = "black")
plt.title("Score Distribution")
plt.show()
# Out:
# 'Median: 18.0'
# 'Mean: 22.1'
# '3rd Quartile: 30.0'

# %% [markdown]
# ## Data Tidying (Unaffected by Splitting)

# %%
#nyc_restaurants["INSPECTION TYPE"].value_counts()

# Pre-permit (operation vs non-op...)
# Cycle
# initial
# Reopening
# Compliance
# Re-inspection

# Inspection Type: Pre-permit and Cycle (Inter-Agency Task Force - 375)

# Inspection Purpose: Initial, Re-inspection (if initial 14+ points), 
# (Second) Compliance (Unannounced), and Reopening (implies closed)

# %%
nyc_restaurants["INSPECTION PURPOSE"] = \
[line.split(" / ")[1] for line in nyc_restaurants["INSPECTION TYPE"]]

nyc_restaurants["INSPECTION PURPOSE"] = \
[line.split(" ")[0] for line in nyc_restaurants["INSPECTION PURPOSE"]]

# Group first and second compliance inspections together 
#(# compliance dependent on month of first inspections)
nyc_restaurants["INSPECTION PURPOSE"] = \
nyc_restaurants["INSPECTION PURPOSE"].replace("Second", "Compliance")

nyc_restaurants["INSPECTION TYPE"] = \
[line.split(" ")[0] for line in nyc_restaurants["INSPECTION TYPE"]]

#nyc_restaurants

# %%
nyc_restaurants["INSPECTION TYPE"].value_counts()
# Out:
# Cycle           151854
# Pre-permit       35380
# Inter-Agency       375
# Name: INSPECTION TYPE, dtype: int64

# %% [markdown]
# ## Train Test Split

# %%
X = nyc_restaurants.drop(["GRADE"], axis = 1)
y = nyc_restaurants["GRADE"]

# to maintain CAMIS groupings
seed(SEED)
unique_ids = nyc_restaurants.CAMIS.unique().tolist()
k = int(np.ceil(len(unique_ids)*.7))
train_ids = sample(unique_ids, k)

# %%
lst = []
[lst.append(np.where(X["CAMIS"] == x)[0].tolist()) for x in train_ids]
lst

# flatten list
def flatten_list(l):
    return [item for row in l for item in row]

train_indexes = flatten_list(lst)

X_train = X.iloc[train_indexes]
#131174/187609*100 
# ~70% of data (69.92%)

y_train = y.iloc[train_indexes]

X_test = X.drop(train_indexes, axis = 0)
y_test = y.drop(train_indexes, axis = 0)

X_train = X_train.reset_index(drop = True)
X_test = X_test.reset_index(drop = True)
y_train = y_train.reset_index(drop = True)
y_test = y_test.reset_index(drop = True)

# %%
sns.histplot(y_train.sort_values())
sns.histplot(y_test.sort_values())
plt.title("Distribution of Grades in Train and Test Set")
plt.show()

# %%
#X_test["CRITICAL FLAG"].value_counts()
# connected to violation code/desc
# treat Not Applicable as Not Critical

#X_train = X_train.loc[X_train["CRITICAL FLAG"] != "Not Applicable"]

# %%
#X_test["ACTION"].value_counts()

# %% [markdown]
# ## Imputation

# %%
# missing: building, zip, phone, violation code, violation description, grade date, 
# longitude, latitude
# drop na in building, phone, violation code, violation description, longitude and 
# latitude (cannot logically impute)

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131174 entries, 0 to 131173
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  131174 non-null  int64
#  1   DBA                    131174 non-null  object
#  2   BORO                   131174 non-null  object
#  3   BUILDING               130972 non-null  object
#  4   STREET                 131174 non-null  object
#  5   ZIPCODE                129362 non-null  float64
#  6   PHONE                  131171 non-null  object
#  7   CUISINE DESCRIPTION    131174 non-null  object
#  8   INSPECTION DATE        131174 non-null  object
#  9   ACTION                 131174 non-null  object
#  10  VIOLATION CODE         130747 non-null  object
#  11  VIOLATION DESCRIPTION  130747 non-null  object
#  12  CRITICAL FLAG          131174 non-null  object
#  13  SCORE                  131174 non-null  float64
#  14  GRADE DATE             62396 non-null   object
#  15  RECORD DATE            131174 non-null  object
#  16  INSPECTION TYPE        131174 non-null  object
#  17  Latitude               131019 non-null  float64
#  18  Longitude              131019 non-null  float64
#  19  INSPECTION PURPOSE     131174 non-null  object
# dtypes: float64(4), int64(1), object(15)
# memory usage: 20.0+ MB

# %%
X_train.loc[X_train["GRADE DATE"].isna() == True, "GRADE DATE"] = \
X_train.loc[X_train["GRADE DATE"].isna() == True, "INSPECTION DATE"]

X_test.loc[X_test["GRADE DATE"].isna() == True, "GRADE DATE"] = \
X_test.loc[X_test["GRADE DATE"].isna() == True, "INSPECTION DATE"]

# %% [markdown]
# ## Check Missing Zipcodes for Patterns

# %%
missing_zip = np.where(X_train["ZIPCODE"].isna() == True)
missing_zip = X_train.iloc[missing_zip]
#missing_zip

# %%
X_train.loc[(X_train["BORO"] == "Bronx") & (X_train["STREET"] == "MORRIS PARK AVENUE")]
X_train.loc[(X_train["BORO"] == "Manhattan") & (X_train["STREET"] == "CATHERINE STREET")] # 10038
X_train.loc[(X_train["BORO"] == "Brooklyn") & (X_train["STREET"] == "FLATBUSH AVENUE")]

unique_missing_zip = missing_zip.DBA.unique()
#unique_missing_zip

#[X_train.loc[X_train["DBA"] == restaurant].ZIPCODE for restaurant in unique_missing_zip]

# most resturants zipcode missing for all instances, or have multiple zipcode listed for same location

# %% [markdown]
# ## Update y_train and y_test indexes

# %%
X_train = X_train.dropna()
X_test = X_test.dropna()

train_index = X_train.index
test_index = X_test.index

y_train = y_train.iloc[train_index]
y_test = y_test.iloc[test_index]

# %% [markdown]
# ## Data Cleaning and Feature Engineering

# %%
###### Dates: INSPECTION, GRADE, RECORD (drop)
# Difference between grade and inspection (days to grade??)

X_train["INSPECTION DATE"] = [datetime.strptime(day, "%m/%d/%Y").date() for day in X_train["INSPECTION DATE"]]

X_train["GRADE DATE"] = [datetime.strptime(day, "%m/%d/%Y").date() for day in X_train["GRADE DATE"]]

X_test["INSPECTION DATE"] = [datetime.strptime(day, "%m/%d/%Y").date() for day in X_test["INSPECTION DATE"]]

X_test["GRADE DATE"] = [datetime.strptime(day, "%m/%d/%Y").date() for day in X_test["GRADE DATE"]]

# %%
#X_train.sort_values(by = "INSPECTION DATE")
X_train["POST COVID"] = "0"
X_train.loc[X_train["INSPECTION DATE"].astype('str') >= '2021-03-16', "POST COVID"] = "1"

X_test["POST COVID"] = "0"
X_test.loc[X_test["INSPECTION DATE"].astype('str') >= '2021-03-16', "POST COVID"] = "1"

#X_train

# "the World Health Organization declared a global COVID-19 pandemic on March 11.[8] 
# New York City public schools closed as of March 16, and remote learning began on March 23." 
# - Wikipedia

# %%
(X_train["GRADE DATE"] - X_train["INSPECTION DATE"]).value_counts()
# All days reported same day as inspection
# Out:
# 0 days    128728
# dtype: int64

# %%
# Combine violation descriptions into 1 by restaurant visit

X_train["VIOLATION DESCRIPTION"] = \
X_train.groupby(["CAMIS", "INSPECTION DATE"])["VIOLATION DESCRIPTION"].transform(lambda x: " , ".join(x))

X_test["VIOLATION DESCRIPTION"] = \
X_test.groupby(["CAMIS", "INSPECTION DATE"])["VIOLATION DESCRIPTION"].transform(lambda x: " , ".join(x))

# %%
X_train["CRITICAL FLAG"].value_counts()
# only 1 Not Applicable - drop
x = np.where(X_train["CRITICAL FLAG"] == "Not Applicable")[0][0]
X_train = X_train.drop(x)

X_train["CRITICAL FLAGS PER INSPECTION"] = \
X_train.groupby(["CAMIS", "INSPECTION DATE"])["CRITICAL FLAG"].apply(lambda x : x.eq("Critical").cumsum())

X_test["CRITICAL FLAGS PER INSPECTION"] = \
X_test.groupby(["CAMIS", "INSPECTION DATE"])["CRITICAL FLAG"].apply(lambda x : x.eq("Critical").cumsum())

X_train["VIOLATIONS PER INSPECTION"] = X_train.groupby(["CAMIS", "INSPECTION DATE"]).cumcount()+1

X_test["VIOLATIONS PER INSPECTION"] = X_test.groupby(["CAMIS", "INSPECTION DATE"]).cumcount()+1

# %%
X_train = X_train.loc[X_train.groupby(["CAMIS", "INSPECTION DATE"])["VIOLATIONS PER INSPECTION"].idxmax()]
X_test = X_test.loc[X_test.groupby(["CAMIS", "INSPECTION DATE"])["VIOLATIONS PER INSPECTION"].idxmax()]

# %%
#X_train["CAMIS"].value_counts()#.sort_values()

# %%
# avg number of inspection/year
total_inspections = X_train.groupby(["CAMIS"])["INSPECTION DATE"].count().tolist()

def deltayears(now, birthdate):
    rdelta = relativedelta(now, birthdate)
    return rdelta.years + 1 #*12 + rdelta.months

years_in_data = X_train.groupby("CAMIS").apply(lambda x: deltayears(x["INSPECTION DATE"].max(), 
                                                                    x["INSPECTION DATE"].min())).tolist()

# can make into 1 function**
def months(now, birthdate):
    rdelta = relativedelta(now, birthdate)
    return rdelta.years*12 + rdelta.months

months_in_data = X_train.groupby("CAMIS").apply(lambda x: months(x["INSPECTION DATE"].max(), 
                                                                 x["INSPECTION DATE"].min())).tolist()

# on test data
total_inspections_test = X_test.groupby(["CAMIS"])["INSPECTION DATE"].count().tolist()

years_in_data_test = X_test.groupby("CAMIS").apply(lambda x: deltayears(x["INSPECTION DATE"].max(), 
                                                                        x["INSPECTION DATE"].min())).tolist()

months_in_data_test = X_test.groupby("CAMIS").apply(lambda x: months(x["INSPECTION DATE"].max(), 
                                                                     x["INSPECTION DATE"].min())).tolist()

# %% [markdown]
# ## Visualization

# %%
sns.histplot(X_train["BORO"])
sns.histplot(X_test["BORO"]).set(title = "Borough Histogram of Train and Test")
plt.show()

# %%
# select single restaurant inspection
X_train = X_train.groupby(["CAMIS"]).apply(lambda x: x.sample(1, random_state = SEED))
X_train_index = [i[1] for i in X_train.index]
X_train = X_train.reset_index(drop = True)

X_test = X_test.groupby(["CAMIS"]).apply(lambda x: x.sample(1, random_state = SEED))
X_test_index = [i[1] for i in X_test.index]
X_test = X_test.reset_index(drop = True)

# %%
round(X_train[["BORO", "SCORE"]].groupby("BORO").mean(), 2)
# Out:
#                SCORE
# BORO
# Bronx          16.36
# Brooklyn       17.16
# Manhattan      16.04
# Queens         17.01
# Staten Island  14.90

# %% [markdown]
# ### Select Most Common Cuisines

# %%
#X_train["CUISINE DESCRIPTION"].value_counts().head(30)
#np.where(X_train["CUISINE DESCRIPTION"].value_counts() > 500)
top_cuisines = X_train["CUISINE DESCRIPTION"].value_counts().iloc[0:10]
top_cuisines
# Out:
# American                    3158
# Chinese                     1422
# Coffee/Tea                  1172
# Pizza                       1006
# Italian                      646
# Mexican                      623
# Japanese                     580
# Bakery Products/Desserts     560
# Latin American               550
# Caribbean                    512
# Name: CUISINE DESCRIPTION, dtype: int64

# %%
all_cuisines = X_train["CUISINE DESCRIPTION"].unique()
np.setdiff1d(X_train["CUISINE DESCRIPTION"].unique(), top_cuisines[0])
all_cuisines = all_cuisines[np.isin(all_cuisines, top_cuisines.axes) == False].tolist()
X_train["CUISINE DESCRIPTION"] = X_train["CUISINE DESCRIPTION"].replace(all_cuisines, "Other")

X_test["CUISINE DESCRIPTION"] = X_test["CUISINE DESCRIPTION"].replace(all_cuisines, "Other")

# %%
#X_test["CUISINE DESCRIPTION"].value_counts()
other_cuisines = ["Creole/Cajun", "New French", "Southwestern", "Basque"]
X_test["CUISINE DESCRIPTION"] = X_test["CUISINE DESCRIPTION"].replace(other_cuisines, "Other")

# %% [markdown]
# ## Update y indexes for filtered data

# %%
y_train = y_train[X_train_index].reset_index(drop = True)
y_test = y_test[X_test_index].reset_index(drop = True)

# %%
#X_train.loc[X_train["CAMIS"] == 30075445][["INSPECTION DATE", "CRITICAL FLAG", 
# "CRITICAL FLAGS PER INSPECTION", "VIOLATIONS PER INSPECTION"]]

# %%
# if number inspections > 3*number of years == high risk/many inspections
# does not account for restaurant with many inspections one year but improves overtime

years_array = np.array(years_in_data)
years_array = years_array * 3
max_inspections = years_array.tolist()

X_train["TOTAL INSPECTIONS"] = total_inspections
X_train["RISKY BUSINESS"] = "0"
X_train.loc[X_train["TOTAL INSPECTIONS"] > max_inspections, "RISKY BUSINESS"] = "1"
X_train["MONTHS OPERATING"] = months_in_data


years_array_test = np.array(years_in_data_test)
years_array_test = years_array_test * 3
max_inspections_test = years_array_test.tolist()

X_test["TOTAL INSPECTIONS"] = total_inspections_test
X_test["RISKY BUSINESS"] = "0"
X_test.loc[X_test["TOTAL INSPECTIONS"] > max_inspections_test, "RISKY BUSINESS"] = "1"
X_test["MONTHS OPERATING"] = months_in_data_test

# drop critical flag
# X_train = X_train.drop("CRITICAL FLAG", axis = 1)
# X_test = X_test.drop("CRITICAL FLAG", axis = 1)

# %%
#X_train["CAMIS"].value_counts()

# %%
X_train.ZIPCODE.value_counts()
# 213 unique
# drop zipcodes and use coordinates (inconsistent - some restaurants listed in multiple zipcodes)
# Out:
# 10019.0    395
# 10003.0    374
# 10036.0    370
# 10002.0    322
# 10001.0    307
#           ...
# 10171.0      1
# 11005.0      1
# 10176.0      1
# 11242.0      1
# 10000.0      1
# Name: ZIPCODE, Length: 213, dtype: int64

# %%
# deal with zipcode

X_train["ZIPCODE"] = X_train["ZIPCODE"].astype('int32').astype('str')
[number[0:3] for number in X_train.PHONE]
X_train.PHONE.value_counts()

# X_train.loc[X_train["PHONE"] == "9172843260"]
# some businesses share phone number (ie. food stands, chains (2126159700 for Starbucks))

X_test["ZIPCODE"] = X_test["ZIPCODE"].astype('str')

X_train
# Out:
#           CAMIS                              DBA       BORO BUILDING  \
# 0      30075445            MORRIS PARK BAKE SHOP      Bronx     1007
# 1      30112340                          WENDY'S   Brooklyn      469
# 2      40356018                 RIVIERA CATERERS   Brooklyn     2780
# 3      40356731      TASTE THE TROPICS ICE CREAM   Brooklyn     1839
# 4      40359705                  NATHAN'S FAMOUS   Brooklyn     1310
# ...         ...                              ...        ...      ...
# 16477  50136435              KNICKERBOCKER BAGEL   Brooklyn      367
# 16478  50136507     MILANO PIZZA & FRIED CHICKEN      Bronx     1544
# 16479  50136563                     DOUBLE YOLKK  Manhattan       96
# 16480  50136684  LAS PATRONAS BAR AND RESTAURANT     Queens     2307
# 16481  50136989            HOT SPOT GRILL & JERK      Bronx     4850
#
#                      STREET ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 0        MORRIS PARK AVENUE   10462  7188924968  Bakery Products/Desserts
# 1           FLATBUSH AVENUE   11225  7182875005                     Other
# 2          STILLWELL AVENUE   11224  7183723031                  American
# 3           NOSTRAND AVENUE   11226  7188560821                     Other
# 4               SURF AVENUE   11224  7183332202                     Other
# ...                     ...     ...         ...                       ...
# 16477  KNICKERBOCKER AVENUE   11237  7187098888                     Other
# 16478          BOONE AVENUE   10460  9292469636                     Other
# 16479          SOUTH STREET   10038  6467624749                     Other
# 16480           STEINWAY ST   11105  3473550275                     Other
# 16481     WHITE PLAINS ROAD   10470  3473266244                 Caribbean
#
#       INSPECTION DATE                                           ACTION  ...  \
# 0          2021-08-10  Violations were cited in the following area(s).  ...
# 1          2021-07-20  Violations were cited in the following area(s).  ...
# 2          2019-11-08  Violations were cited in the following area(s).  ...
# 3          2021-08-20  Violations were cited in the following area(s).  ...
# 4          2022-02-10  Violations were cited in the following area(s).  ...
# ...               ...                                              ...  ...
# 16477      2023-05-31  Violations were cited in the following area(s).  ...
# 16478      2023-05-30  Violations were cited in the following area(s).  ...
# 16479      2023-05-23  Violations were cited in the following area(s).  ...
# 16480      2023-05-26  Violations were cited in the following area(s).  ...
# 16481      2023-06-01  Violations were cited in the following area(s).  ...
#
#       INSPECTION TYPE   Latitude  Longitude  INSPECTION PURPOSE POST COVID  \
# 0               Cycle  40.848231 -73.855972             Initial          1
# 1               Cycle  40.662652 -73.962081             Initial          1
# 2               Cycle  40.579920 -73.982090             Initial          0
# 3               Cycle  40.640795 -73.948488             Initial          1
# 4               Cycle  40.575537 -73.981652             Initial          1
# ...               ...        ...        ...                 ...        ...
# 16477      Pre-permit  40.700528 -73.921368             Initial          1
# 16478      Pre-permit  40.832998 -73.885099             Initial          1
# 16479      Pre-permit  40.706374 -74.002882             Initial          1
# 16480      Pre-permit  40.770867 -73.908461             Initial          1
# 16481      Pre-permit  40.906572 -73.848812             Initial          1
#
#       CRITICAL FLAGS PER INSPECTION VIOLATIONS PER INSPECTION  \
# 0                                 1                         1
# 1                                 2                         2
# 2                                 1                         3
# 3                                 1                         3
# 4                                 1                         3
# ...                             ...                       ...
# 16477                             4                         7
# 16478                             0                         1
# 16479                             0                         1
# 16480                             1                         3
# 16481                             8                        10
#
#        TOTAL INSPECTIONS  RISKY BUSINESS MONTHS OPERATING
# 0                      3               0               17
# 1                      3               0               11
# 2                      2               0               26
# 3                      2               0               16
# 4                      2               0               14
# ...                  ...             ...              ...
# 16477                  1               0                0
# 16478                  1               0                0
# 16479                  1               0                0
# 16480                  1               0                0
# 16481                  1               0                0
#
# [16482 rows x 26 columns]

# %%
X_train.ZIPCODE.value_counts()
# Out:
# 10019    395
# 10003    374
# 10036    370
# 10002    322
# 10001    307
#         ...
# 10171      1
# 11005      1
# 10176      1
# 11242      1
# 10000      1
# Name: ZIPCODE, Length: 213, dtype: int64

# %%
# convert date to day, month, year

X_train[["YEAR", "MONTH", "DAY"]] = X_train["INSPECTION DATE"].astype("str").str.split("-", expand = True)
X_train = X_train.drop("INSPECTION DATE", axis = 1)
# year-month-day
X_test[["YEAR", "MONTH", "DAY"]] = X_test["INSPECTION DATE"].astype("str").str.split("-", expand = True)
X_test = X_test.drop("INSPECTION DATE", axis = 1)

# %% [markdown]
# ## Finalize X_train and X_test

# %%
X_train = X_train.drop(["CAMIS", "DBA", "BUILDING", "STREET", "ZIPCODE", "PHONE", 
                        "ACTION", "VIOLATION CODE", "SCORE", "CRITICAL FLAG", 
                        "RECORD DATE", "GRADE DATE"], axis = 1)

X_test = X_test.drop(["CAMIS", "DBA", "BUILDING", "STREET", "ZIPCODE", "PHONE", 
                      "ACTION", "VIOLATION CODE", "SCORE", "CRITICAL FLAG", 
                      "RECORD DATE", "GRADE DATE"], axis = 1)

X_train
# Out:
#             BORO       CUISINE DESCRIPTION  \
# 0          Bronx  Bakery Products/Desserts
# 1       Brooklyn                     Other
# 2       Brooklyn                  American
# 3       Brooklyn                     Other
# 4       Brooklyn                     Other
# ...          ...                       ...
# 16477   Brooklyn                     Other
# 16478      Bronx                     Other
# 16479  Manhattan                     Other
# 16480     Queens                     Other
# 16481      Bronx                 Caribbean
#
#                                    VIOLATION DESCRIPTION INSPECTION TYPE  \
# 0      Sanitized equipment or utensil, including in-u...           Cycle
# 1      Food contact surface not properly washed, rins...           Cycle
# 2      Food contact surface not properly washed, rins...           Cycle
# 3      Facility not vermin proof. Harborage or condit...           Cycle
# 4      Food contact surface not properly washed, rins...           Cycle
# ...                                                  ...             ...
# 16477  Cold TCS food item held above 41 °F; smoked or...      Pre-permit
# 16478  Non-food contact surface or equipment made of ...      Pre-permit
# 16479  Non-food contact surface or equipment made of ...      Pre-permit
# 16480  Non-food contact surface or equipment made of ...      Pre-permit
# 16481  Filth flies or food/refuse/sewage associated w...      Pre-permit
#
#         Latitude  Longitude INSPECTION PURPOSE POST COVID  \
# 0      40.848231 -73.855972            Initial          1
# 1      40.662652 -73.962081            Initial          1
# 2      40.579920 -73.982090            Initial          0
# 3      40.640795 -73.948488            Initial          1
# 4      40.575537 -73.981652            Initial          1
# ...          ...        ...                ...        ...
# 16477  40.700528 -73.921368            Initial          1
# 16478  40.832998 -73.885099            Initial          1
# 16479  40.706374 -74.002882            Initial          1
# 16480  40.770867 -73.908461            Initial          1
# 16481  40.906572 -73.848812            Initial          1
#
#        CRITICAL FLAGS PER INSPECTION  VIOLATIONS PER INSPECTION  \
# 0                                  1                          1
# 1                                  2                          2
# 2                                  1                          3
# 3                                  1                          3
# 4                                  1                          3
# ...                              ...                        ...
# 16477                              4                          7
# 16478                              0                          1
# 16479                              0                          1
# 16480                              1                          3
# 16481                              8                         10
#
#        TOTAL INSPECTIONS RISKY BUSINESS  MONTHS OPERATING  YEAR MONTH DAY
# 0                      3              0                17  2021    08  10
# 1                      3              0                11  2021    07  20
# 2                      2              0                26  2019    11  08
# 3                      2              0                16  2021    08  20
# 4                      2              0                14  2022    02  10
# ...                  ...            ...               ...   ...   ...  ..
# 16477                  1              0                 0  2023    05  31
# 16478                  1              0                 0  2023    05  30
# 16479                  1              0                 0  2023    05  23
# 16480                  1              0                 0  2023    05  26
# 16481                  1              0                 0  2023    06  01
#
# [16482 rows x 16 columns]

# %%
# save as csv files

#X_train.to_csv(PATH + "X_train_restaurants.csv")
#X_test.to_csv(PATH + "X_test_restaurants.csv")
#y_train.to_csv(PATH + "y_train_restaurants.csv")
#y_test.to_csv(PATH + "y_test_restaurants.csv")
